# %%
import numpy as np
import pandas as pd

import datetime

# %%
x = datetime.datetime.now()
print(x)
# Out:
# 2024-10-04 04:45:43.106051

# %%
y = datetime.datetime(2005, 4, 29)
print(y)
# Out:
# 2005-04-29 00:00:00

# %%
print("day of your bithday:",y.strftime("%A"))
# Out:
# day of your bithday: Friday

# %%
age_year = x.year - y.year
print("year",age)
age_month = x.month - y.month
print("month",age_month)
age_day = x.day - y.day
print("day",-(age_day),"old")
# Out:
# year 19
# month 6
# day 25 old

# %%
range = pd.date_range(start = y, end = x, freq="y")
df= pd.DataFrame(range)
df.head(10)
# Out:
# <ipython-input-23-7f15c77d5a3b>:1: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   range = pd.date_range(start = y, end = x, freq="y")
#            0
# 0 2005-12-31
# 1 2006-12-31
# 2 2007-12-31
# 3 2008-12-31
# 4 2009-12-31
# 5 2010-12-31
# 6 2011-12-31
# 7 2012-12-31
# 8 2013-12-31
# 9 2014-12-31

# %%
# prompt: Using dataframe df: use window function

# Import necessary libraries
import pandas as pd

# Assuming your dataframe is called 'df' and your date column is named 'date'
# Replace 'date' with the actual column name if different

# Calculate rolling average of 3 years
df['rolling_avg'] = df[0].rolling(window=3, center=True).mean()

# Example using expanding mean (cumulative average)
df['expanding_mean'] = df[0].expanding().mean()

# Print the updated dataframe
print(df)
